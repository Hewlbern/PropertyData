# %%
import requests
import json



import matplotlib.pyplot as plt
import seaborn as sns

from pandasdmx import Request
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import pandas as pd
import numpy as np
import geopandas as gpd

import time

import csv

import sys, os
from sqlalchemy import create_engine

import pymssql
import sqlalchemy as db

from functools import reduce

import folium # map rendering library
from sklearn.neighbors import NearestNeighbors
# Out:
# /home/holborn/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %% [markdown]
# ### Here API

# %%
API_Key = 't9X9EF_AkG_qVZ8Q4dWSgyJuMhSklDP7i_gqX5EMunQ'
URL = 'https://router.hereapi.com/v8/routes?'
# TRANSPORTMODE ='transportMode=pedestrian' 
PARAMS = '&origin=-37.8046041,144.9454422&destination=-37.8102306,144.9539645&return=polyline,summary&apikey='

TRANSPORTMODE ='pedestrian' 

RETURN = 'polyline'

DESTINATION_X = '-37.8102306'
DESTINATION_Y = '144.9539645'
ORIGIN_X = '-37.8046041'
ORIGIN_Y = '144.9454422'

# %% [markdown]
# ### Get Travel Time

# %%
def get_transport(TRANSPORTMODE, ORIGIN_X,ORIGIN_Y,DESTINATION_X,DESTINATION_Y,RETURN ,API_Key):
    
    #print(nb)
    
    #form the request url and request only the items (which are the venues)
    url = 'https://router.hereapi.com/v8/routes?transportMode={}&origin={},{}&destination={},{}&return={},summary&apikey={}'.format(TRANSPORTMODE, ORIGIN_X,ORIGIN_Y,DESTINATION_X,DESTINATION_Y,RETURN ,API_Key)
    items = requests.get(url).json()['routes'][0]['sections']
    transport = json_normalize(items).set_index('id')
    print(url)
    #include exception handling where Foursquare request fails for a particular Neighbourhood
    if items == []:
        print(" -- HERO request for ",nb,"returned no results --")
        return None
    return transport

# %% [markdown]
# ### FourSquare API

# %%
#intialise Foursquare API credentials
url = 'https://api.foursquare.com/v2/venues/explore'


CLIENT_ID = 'ZY2UKTXC3KLI2DSJYFZPC3CPXMU4SGKILQOKDZK5FAMGXB2C' # your Foursquare ID
CLIENT_SECRET = '0D0TWC2MD2NDOHUUXRAYAS1DRQRAA2E14Z33QU01YADTE0O1' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version


# #intialise Foursquare API credentials
# CLIENT_ID = 'EKC0OWGJC1SY1AE1UHB4PUPH2JGARZTQK1U5C1USTUNA43JF' # your Foursquare ID
# CLIENT_SECRET = 'CHH0EPUEN2PH4WBDV4XHTDT5NWTUZ2SYVIQALUOZXWYNABRO' # your Foursquare Secret

# %% [markdown]
# ### Postcodes

# %%
postcodes = pd.read_csv('Datasets/Australian_Post_Codes_Lat_Lon.csv')
postcodes.drop_duplicates(subset='suburb', inplace=True)
postcodes.drop(['dc', 'type'],axis=1,inplace=True )
postcodes.dropna(inplace=True) #drop the trailing row which has no data
postcodes.reset_index(inplace=True, drop=True) #reinex after having removed some rows above
postcodes.shape
postcodes.head()
# Out:
#    postcode                          suburb state        lat         lon
# 0       200  AUSTRALIAN NATIONAL UNIVERSITY   ACT -35.277272  149.117136
# 1       221                          BARTON   ACT -35.201372  149.095065
# 2       800                          DARWIN    NT -12.801028  130.955789
# 3       804                           PARAP    NT -12.432181  130.843310
# 4       810                           ALAWA    NT -12.378451  130.877014

# %%
melb_postcodes = postcodes[(postcodes['postcode']>=3000)&(postcodes['postcode']<=3207)|(postcodes['postcode']>=8000)&(postcodes['postcode']<=8499)]
melb_postcodes.head()
# Out:
#       postcode              suburb state        lat         lon
# 4901      3000           MELBOURNE   VIC -37.814563  144.970267
# 4902      3002      EAST MELBOURNE   VIC -37.816640  144.987811
# 4903      3003      WEST MELBOURNE   VIC -37.806255  144.941123
# 4904      3005  WORLD TRADE CENTRE   VIC -37.822262  144.954856
# 4905      3006           SOUTHBANK   VIC -37.823258  144.965926

# %% [markdown]
# ### Get Venues

# %%
#Use the function to extract the category from the dataframe (because the column name could be either 'categories' or 'venue.categories')
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


#define a function to return all the venues for a given neighborhood

#pass the neighborhood (nb), the latitude (la), the radius and the limit 
def get_venues(nb, la, lo, radius, limit):
    
    #print(nb)
    
    #form the request url and request only the items (which are the venues)
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, la, lo, VERSION, limit)
    items = requests.get(url).json()["response"]['groups'][0]['items']
    
    #include exception handling where Foursquare request fails for a particular Neighbourhood
    if items == []:
        print(" -- Foursquare request for ",nb,"returned no results --")
        return None
    else:
        # flatten JSON, filter for only wanted columns then use the get_category_type funtion to replace the category list with just the category.
        venues1 = json_normalize(items)
        filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
        venues1 =venues1.loc[:, filtered_columns]
        venues1['venue.categories'] = venues1.apply(get_category_type, axis=1)

        #define a new dataframe with the Neighbourhood information
        venues2 = pd.DataFrame(columns=['Suburb','Suburb Latitude', 
                      'Suburb Longitude']) 

        #for each of the venues returned, add the venue dataframe to the (empty) neighbourhood dataframe and fill all rows in the the neighbourhood columns with the neighborhood name, the neighbourhood latitude and longitude
        i=0
        for row in venues1:
            venues2[row]=venues1[row]
            venues2['Suburb']=nb
            venues2['Suburb Latitude']=la
            venues2['Suburb Longitude']=lo
            i=i+1

        #rename the columns
        venues2.rename(index=str,columns={"venue.name":"Venue","venue.categories":"Venue Category","venue.location.lat":"Venue Latitude","venue.location.lng":"Venue Longitude"}, inplace=True)
    
    return venues2

# %% [markdown]
# ### Call API

# %%
transport  = get_transport(TRANSPORTMODE, ORIGIN_X,ORIGIN_Y,DESTINATION_X,DESTINATION_Y,RETURN ,API_Key)
transport
# Out:
# https://router.hereapi.com/v8/routes?transportMode=pedestrian&origin=-37.8046041,144.9454422&destination=-37.8102306,144.9539645&return=polyline,summary&apikey=t9X9EF_AkG_qVZ8Q4dWSgyJuMhSklDP7i_gqX5EMunQ
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                             type  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6  pedestrian
#
#                                                                                polyline  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6  BGtotjoCux4u0I5DyoBrEkwBvC0enB4STgFTsEnBsEnB4D...
#
#                                                  departure.time  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6  2020-12-20T23:51:19+11:00
#
#                                      departure.place.type  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                place
#
#                                       departure.place.location.lat  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                    -37.804679
#
#                                       departure.place.location.lng  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                    144.945431
#
#                                       departure.place.originalLocation.lat  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                            -37.804604
#
#                                       departure.place.originalLocation.lng  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                            144.945442
#
#                                                    arrival.time  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6  2020-12-21T00:08:45+11:00
#
#                                      arrival.place.type  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6              place
#
#                                       arrival.place.location.lat  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                  -37.810234
#
#                                       arrival.place.location.lng  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                  144.953962
#
#                                       arrival.place.originalLocation.lat  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                          -37.810231
#
#                                       arrival.place.originalLocation.lng  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6                          144.953965
#
#                                       summary.duration  summary.length  \
# id
# efb71811-c925-4358-aae4-781073f8ddc6              1046            1039
#
#                                       summary.baseDuration transport.mode
# id
# efb71811-c925-4358-aae4-781073f8ddc6                  1046     pedestrian

# %% [markdown]
# #### HERE API Call for postcode

# %%
#Iterate thorough all the suburbs of the dataframe df, adding each set of venues to the df_suburb_venues dataframe
#df=melb_postcodes
df=postcodes
df_suburb_venues=pd.DataFrame()
radius = 500
limit = 10000
print("Getting venue recommendations, please wait......")
for i, row in enumerate(df['suburb']):
        df_suburb_venues=df_suburb_venues.append(get_venues(df.iloc[i]['suburb'], df.iloc[i]['lat'], df.iloc[i]['lon'], radius, limit),ignore_index=True)
print("...... Complete")
# Out:
# Getting venue recommendations, please wait......
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:31: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#  -- Foursquare request for  DALY RIVER returned no results --
#  -- Foursquare request for  FLEMING returned no results --
#  -- Foursquare request for  NGUIU returned no results --
#  -- Foursquare request for  LAJAMANU returned no results --
#  -- Foursquare request for  WAVE HILL returned no results --
#  -- Foursquare request for  BORROLOOLA returned no results --
#  -- Foursquare request for  BRUNCHILLY returned no results --
#  -- Foursquare request for  AVON DOWNS returned no results --
#  -- Foursquare request for  CRESSWELL DOWNS returned no results --
#  -- Foursquare request for  MUCKATY STATION returned no results --
#  -- Foursquare request for  NEWCASTLE WATERS returned no results --
#  -- Foursquare request for  WOLLOGORANG STATION returned no results --
#  -- Foursquare request for  AMATA returned no results --
#  -- Foursquare request for  GIBSON DESERT NORTH returned no results --
#  -- Foursquare request for  SANTA TERESA returned no results --
#  -- Foursquare request for  WILLOWRA returned no results --
#  -- Foursquare request for  YUELAMU returned no results --
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-164-d8260d28c8b6> in <module>
#       7 print("Getting venue recommendations, please wait......")
#       8 for i, row in enumerate(df['suburb']):
# ----> 9         df_suburb_venues=df_suburb_venues.append(get_venues(df.iloc[i]['suburb'], df.iloc[i]['lat'], df.iloc[i]['lon'], radius, limit),ignore_index=True)
#      10 print("...... Complete")
#
# <ipython-input-162-bffd7fc47f96> in get_venues(nb, la, lo, radius, limit)
#      29     else:
#      30         # flatten JSON, filter for only wanted columns then use the get_category_type funtion to replace the category list with just the category.
# ---> 31         venues1 = json_normalize(items)
#      32         filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
#      33         venues1 =venues1.loc[:, filtered_columns]
#
# /home/holborn/snap/jupyter/common/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      64     def wrapper(*args, **kwargs) -> Callable[..., Any]:
#      65         warnings.warn(warning_msg, klass, stacklevel=stacklevel)
# ---> 66         return alternative(*args, **kwargs)
#      67
#      68     # adding deprecated directive to the docstring
#
# /home/holborn/snap/jupyter/common/lib/python3.7/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     280             # TODO: handle record value which are lists, at least error
#     281             #       reasonably
# --> 282             data = nested_to_record(data, sep=sep, max_level=max_level)
#     283         return DataFrame(data)
#     284     elif not isinstance(record_path, list):
#
# /home/holborn/snap/jupyter/common/lib/python3.7/site-packages/pandas/io/json/_normalize.py in nested_to_record(ds, prefix, sep, level, max_level)
#      81     new_ds = []
#      82     for d in ds:
# ---> 83         new_d = copy.deepcopy(d)
#      84         for k, v in d.items():
#      85             # each key gets renamed with prefix
#
# /snap/jupyter/6/lib/python3.7/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /snap/jupyter/6/lib/python3.7/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# /snap/jupyter/6/lib/python3.7/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /snap/jupyter/6/lib/python3.7/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# /snap/jupyter/6/lib/python3.7/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /snap/jupyter/6/lib/python3.7/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# /snap/jupyter/6/lib/python3.7/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /snap/jupyter/6/lib/python3.7/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# KeyboardInterrupt:

# %%
venue_property = "Datasets/venue_datasets_largest.csv"
df_suburb_venues = pd.read_csv(venue_property)
df_suburb_venues['Venue Category'].unique()
# Out:
# array(['Speakeasy', 'Boutique', 'Peruvian Restaurant', 'Bakery',
#        'Vietnamese Restaurant', 'Asian Restaurant', 'Hotel', 'Whisky Bar',
#        'Street Art', 'Italian Restaurant', 'Bookstore',
#        'French Restaurant', 'Café', 'Sushi Restaurant',
#        'Australian Restaurant', 'Indian Restaurant', 'Coffee Shop', 'Bar',
#        'Wine Bar', 'Theater', 'BBQ Joint', 'Burger Joint',
#        'Armenian Restaurant', 'Argentinian Restaurant', 'Lounge',
#        'Spanish Restaurant', 'Tapas Restaurant', 'Japanese Restaurant',
#        'Cocktail Bar', 'Museum', 'Steakhouse', 'Art Gallery',
#        'Movie Theater', 'Juice Bar', 'Hotel Bar', 'Plaza', 'Creperie',
#        'Comic Shop', 'Mexican Restaurant', 'Soba Restaurant',
#        'Deli / Bodega', 'Chocolate Shop', 'Dumpling Restaurant',
#        'Sandwich Place', 'Performing Arts Venue', 'Ice Cream Shop',
#        'Road', 'Shanghai Restaurant', 'Thai Restaurant', 'Park',
#        'Ramen Restaurant', 'Chinese Restaurant', 'Cricket Ground',
#        'Breakfast Spot', 'Vegetarian / Vegan Restaurant',
#        'Football Stadium', 'Pub', 'Tennis Stadium', 'Garden',
#        'Restaurant', 'Tennis Court', 'Food & Drink Shop', 'Gastropub',
#        'Grocery Store', 'Korean Restaurant', 'Butcher', 'Pizza Place',
#        'Track', 'Fish & Chips Shop', 'Gym', 'Greek Restaurant',
#        'Taco Place', 'Dessert Shop', 'Theme Park', 'Pool',
#        'Theme Park Ride / Attraction', 'Buffet', 'African Restaurant',
#        'Dog Run', 'Gaming Cafe', 'Indonesian Restaurant',
#        'Middle Eastern Restaurant', 'Warehouse Store',
#        'Seafood Restaurant', 'Donut Shop', 'Indie Theater',
#        'Shopping Mall', 'Cambodian Restaurant', 'Supermarket',
#        'Playground', 'Korean BBQ Restaurant', 'Portuguese Restaurant',
#        'Turkish Restaurant', 'Sculpture Garden', 'Stadium',
#        'Skating Rink', 'Concert Hall', 'Diner', 'Arcade', 'Brewery',
#        'Golf Course', 'Gift Shop', 'Light Rail Station',
#        'Gym / Fitness Center', 'Bagel Shop', 'Kebab Restaurant',
#        'Chaat Place', 'Casino', 'Fried Chicken Joint', 'Candy Store',
#        'Beer Garden', 'Harbor / Marina', 'Social Club', 'Clothing Store',
#        'Fast Food Restaurant', 'Building', 'History Museum',
#        'Cantonese Restaurant', 'School', 'Bridge', 'Outlet Mall',
#        'Opera House', 'Pedestrian Plaza', 'Trail', 'Malay Restaurant',
#        'Music Venue', 'Skate Park', 'Gourmet Shop', 'Pet Store',
#        'Pharmacy', 'Nightclub', 'Sports Bar', 'Tunnel', 'Mini Golf',
#        'Lebanese Restaurant', 'German Restaurant', 'Salad Place',
#        'Train Station', 'Frozen Yogurt Shop', 'Cheese Shop',
#        'Outdoors & Recreation', 'Indie Movie Theater',
#        'Yunnan Restaurant', 'Athletics & Sports', 'Persian Restaurant',
#        'Egyptian Restaurant', 'College Quad', 'Dance Studio', 'Aquarium',
#        'Pakistani Restaurant', 'Soup Place', 'College Gym', 'Food Court',
#        'Convenience Store', 'Wine Shop', 'Beer Bar', 'Miscellaneous Shop',
#        'Eastern European Restaurant', 'Food Truck', 'Racecourse',
#        'Karaoke Bar', 'Bowling Green', 'Science Museum', 'Cupcake Shop',
#        'Planetarium', 'Post Office', 'Go Kart Track',
#        'Latin American Restaurant', 'Filipino Restaurant',
#        'Electronics Store', 'Arts & Crafts Store', 'Farmers Market',
#        'Thrift / Vintage Store', 'Afghan Restaurant', 'Food',
#        'Furniture / Home Store', 'Campground', 'Badminton Court', 'Beach',
#        'Hockey Field', 'Paper / Office Supplies Store', 'Pier',
#        'Gas Station', 'Department Store', 'Mediterranean Restaurant',
#        'Bowling Alley', 'Racetrack', 'General Entertainment', 'Multiplex',
#        'Liquor Store', 'Cretan Restaurant', 'Market', 'Bubble Tea Shop',
#        'Noodle House', 'Big Box Store', 'Business Service', 'Kids Store',
#        'South Indian Restaurant', 'Music Store', 'Swim School',
#        'Flea Market', 'Shipping Store', 'Soccer Field',
#        'Rental Car Location', 'Recreation Center', 'Video Store',
#        'Bus Line', 'National Park', 'Bus Stop', 'Sporting Goods Shop',
#        'Exhibit', 'Video Game Store', 'Discount Store',
#        'Monument / Landmark', 'Zoo', 'Falafel Restaurant',
#        'Airport Terminal', 'Cosmetics Shop', 'Tourist Information Center',
#        'Baseball Stadium', 'Ethiopian Restaurant', 'Zoo Exhibit',
#        'Hockey Arena', 'Sri Lankan Restaurant', 'Sports Club',
#        'Scenic Lookout', 'Veterinarian', 'Airport Lounge', 'Airport',
#        'Motel', 'Airport Service', 'Duty-free Shop', 'Newsstand',
#        'Board Shop', 'Dive Bar', 'General Travel', 'Drive-in Theater',
#        'Yemeni Restaurant', 'Pastry Shop', 'South American Restaurant',
#        'Farm', 'River', 'Basketball Court', 'Lake', 'Night Market',
#        'Jewelry Store', 'Train', 'Rock Club', 'Tibetan Restaurant',
#        'Community Center', 'Cultural Center', 'Street Food Gathering',
#        'Luggage Store', 'Sake Bar', 'Garden Center', 'Climbing Gym',
#        'Bike Rental / Bike Share', 'Burrito Place',
#        'Indonesian Meatball Place', 'Optical Shop', 'Yoga Studio',
#        'Pie Shop', 'RV Park', 'Szechuan Restaurant', 'Accessories Store',
#        'Halal Restaurant', 'American Restaurant', 'Gym Pool',
#        'Shoe Store', 'Roof Deck', 'Jazz Club', 'Office', 'Flower Shop',
#        'Arepa Restaurant', 'Tea Room', 'Camera Store', 'Costume Shop',
#        'Massage Studio', 'Other Great Outdoors', 'Vineyard', 'Resort',
#        'Winery', 'Bed & Breakfast', 'Peking Duck Restaurant',
#        'Taiwanese Restaurant', 'Church', 'Fish Market', 'Baseball Field',
#        'Botanical Garden', 'Antique Shop', 'Water Park', 'Mountain',
#        'Beer Store', 'Rock Climbing Spot', 'Austrian Restaurant',
#        'Burmese Restaurant', 'Gay Bar', 'Pool Hall', 'Dim Sum Restaurant',
#        'IT Services', 'Other Nightlife', 'Fruit & Vegetable Store',
#        'Temple', 'Basketball Stadium', 'Forest',
#        'Construction & Landscaping', 'Toy / Game Store', 'Event Service',
#        'Health Food Store', 'Piercing Parlor', 'Record Shop',
#        'Modern European Restaurant', 'Spa', 'University',
#        'Nature Preserve', 'Indian Chinese Restaurant',
#        'Salon / Barbershop', 'Event Space', 'Bike Shop',
#        'Volleyball Court', 'Mobile Phone Shop', 'Russian Restaurant',
#        'Hungarian Restaurant', 'Molecular Gastronomy Restaurant',
#        'Jewish Restaurant', "Women's Store", 'Hobby Shop',
#        'Outdoor Sculpture', 'Field', 'Hookah Bar', 'Xinjiang Restaurant',
#        'Buddhist Temple', 'Surf Spot', 'Paintball Field',
#        'Martial Arts School', 'Frame Store', 'Polish Restaurant',
#        'Beach Bar', 'College Theater', 'Hostel', 'Ski Area',
#        'Carpet Store', 'Kitchen Supply Store', 'Fishing Spot',
#        'Boxing Gym', 'Scandinavian Restaurant', 'Library',
#        'Gluten-free Restaurant', 'Hot Dog Joint', 'Brazilian Restaurant',
#        'City Hall', 'Shopping Plaza'], dtype=object)

# %%
df_suburb_venues
# Out:
#                        Suburb  Suburb Latitude  Suburb Longitude  \
# 0                   MELBOURNE       -37.814563        144.970267
# 1                   MELBOURNE       -37.814563        144.970267
# 2                   MELBOURNE       -37.814563        144.970267
# 3                   MELBOURNE       -37.814563        144.970267
# 4                   MELBOURNE       -37.814563        144.970267
# ...                       ...              ...               ...
# 37635  LITTLE LONSDALE STREET       -37.811301        144.961819
# 37636  LITTLE LONSDALE STREET       -37.811301        144.961819
# 37637  LITTLE LONSDALE STREET       -37.811301        144.961819
# 37638  LITTLE LONSDALE STREET       -37.811301        144.961819
# 37639  LITTLE LONSDALE STREET       -37.811301        144.961819
#
#                        Venue         Venue Category  Venue Latitude  \
# 0                 Eau de Vie              Speakeasy      -37.815748
# 1              Louis Vuitton               Boutique      -37.814842
# 2                    Pastuso    Peruvian Restaurant      -37.815354
# 3         Lune Croissanterie                 Bakery      -37.815514
# 4                       Coda  Vietnamese Restaurant      -37.815625
# ...                      ...                    ...             ...
# 37635  Queen Victoria Market                 Market      -37.806899
# 37636           Wunderkammer           Antique Shop      -37.813137
# 37637                Grill'd           Burger Joint      -37.810722
# 37638             Gewürzhaus           Gourmet Shop      -37.815924
# 37639   Michelangelo Osteria     Italian Restaurant      -37.813734
#
#        Venue Longitude
# 0           144.971542
# 1           144.969268
# 2           144.971062
# 3           144.969415
# 4           144.969906
# ...                ...
# 37635       144.957954
# 37636       144.959388
# 37637       144.965694
# 37638       144.964628
# 37639       144.960208
#
# [37640 rows x 7 columns]

# %%
postcodes
# Out:
#        postcode                          suburb state        lat         lon
# 0           200  AUSTRALIAN NATIONAL UNIVERSITY   ACT -35.277272  149.117136
# 1           221                          BARTON   ACT -35.201372  149.095065
# 2           800                          DARWIN    NT -12.801028  130.955789
# 3           804                           PARAP    NT -12.432181  130.843310
# 4           810                           ALAWA    NT -12.378451  130.877014
# ...         ...                             ...   ...        ...         ...
# 14264      8004                   ST KILDA ROAD   VIC -37.836219  144.975549
# 14265      8006                 ABECKETT STREET   VIC -37.809696  144.959314
# 14266      8009                   FLINDERS LANE   VIC -37.817201  144.964531
# 14267      8010                      LAW COURTS   VIC -38.185857  146.293728
# 14268      8011          LITTLE LONSDALE STREET   VIC -37.811301  144.961819
#
# [14269 rows x 5 columns]
